# %% [markdown]
# <a href="https://colab.research.google.com/github/febriani6201-lang/KKASmt1-DianRF-X7/blob/main/Tipe_Variabel_Febri_X_7_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Dian Retno Febriani
#
# Kelas: X. 7
#
# No Absen:10

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("febriani6201@gmail.com")
print("febriani6201@gmail.com")
print("febriani6201@gmail.com")
print("febriani6201@gmail.com")
# Out:
# febriani6201@gmail.com
# febriani6201@gmail.com
# febriani6201@gmail.com
# febriani6201@gmail.com

# %%
email_siswa = "febriani6201@gmail.com"

print(email_siswa)
print(email_siswa)
print(email_siswa)
print(email_siswa)
# Out:
# febriani6201@gmail.com
# febriani6201@gmail.com
# febriani6201@gmail.com
# febriani6201@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Hanya boleh menggunakan huruf, angka, dan _

tinggibadan1=170
tinggibadan2=165

print(tinggibadan1)
print(tinggibadan2)

#Contoh salah, menggunakan spasi
# tinggi badan 1= 170
# tinggi badan 2= 165

# print(tinggi badan1)
# print(tinggi badan2)
# Out:
# 170
# 165

# %%
# tidak boleh didahului oleh angka
1tinggibadan =170
2tinggibadan =165

print (1tinggibadan)
print (2tinggibadan)
# Out:
#   File "/tmp/ipython-input-2916429989.py", line 2
#     1tinggibadan =170
#     ^
# SyntaxError: invalid decimal literal

# %%
# case sensitive terhadap kapital

tinggibadan3 = 160
tinggibadan4 = 175

print(tinggibadan3)
print(tinggibadan4)

#contohsalah(Tidak dikenal) :
#print(Tinggibadan3)
#print(Tinggibadan4)
# Out:
# 160
# 175

# %%
#Tidak boleh menggunakan kata kunci python

nif = 200
print(nif)

#contoh salah if
#if = 200
#print(if)
# Out:
# 200

# %%
Print = 15
print(Print)
# Out:
# 15

# %%
prin = 15

print(prin)
# Out:
# 15

# %%
# Contoh salah

# print = 15

# print(print)

# %%
# Tidak deskriptif
_ = "Dian Retno"

print(_)

#Deskriptif
nama_guru = "Pak Kamsan"

print(nama_guru)
# Out:
# Dian Retno
# Pak Kamsan

# %% [markdown]
# #Assignment

# %%
#Single assignment

harga_buku_sidu=5000

print (harga_buku_sidu)
# Out:
# 5000

# %%
#Multiple Assignment

harga_rinso, harga_molto= 30000,5000

print(harga_molto)
print(harga_rinso)
# Out:
# 5000
# 30000

# %%
#Assignment yang sama

harga_kecap_sedap = harga_kecap_bango =15000

print(harga_kecap_sedap)
print(harga_kecap_bango)
# Out:
# 15000
# 15000

# %% [markdown]
# #Latihan Soal Assignment

# %%
#Singgle Assignment
nama="Andi"

print(nama)
# Out:
# Andi

# %%
#Multiplay Assignment
nama, umur, kelas = "Budi", 15, "9A"

print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %%
#Chain Assignment
berat_andi = berat_siti = berat_eko = 45.5

print(berat_andi, berat_siti, berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #Aritmatika

# %%
#Tanpa disimpan ke variabel
print (5000*3)
# Out:
# 15000

# %%
#Simpan operand ke variabel

harga_cilok=6000
banyak_porsi=3

print(harga_cilok*banyak_porsi)
# Out:
# 18000

# %%
#Simpab hasil operasi ke variabel

jumlah_uang_yang_dibayarkan=7000*3

print(jumlah_uang_yang_dibayarkan)
# Out:
# 21000

# %%
#Simpan operand dan hasil operasi ke variabel
harga_kojek=10000
jumlah_porsi_kojek=5
total_harga_kojek= harga_kojek*jumlah_porsi_kojek

print(total_harga_kojek)
# Out:
# 50000

# %%
uang_yang_diberi = 100000
uang_kembalian = uang_yang_diberi-total_harga_kojek

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Soal

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol=24*3

print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kadus=24
jumlah_kardus=3
total_jumlah_botol= banyak_botol_per_kadus*jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Jenis jenis Operator Aritmatika

# %%
#Penjumlahan

jet_pribadi_deo = 21
jet_pribadi_rizal= 8

total_jet_pribadi = jet_pribadi_deo + jet_pribadi_rizal

print(total_jet_pribadi)
# Out:
# 29

# %%
#Pengurangan

jet_pribadi_deo = 21
jet_pribadi_rizal = 8

selisih_jet_pribadi =jet_pribadi_deo-jet_pribadi_rizal

print(selisih_jet_pribadi)
# Out:
# 13

# %%
#PERKALIAN

jumlah_garasi_jet_deo = 3
jumlah_jet_per_garasi = 7

total_jet_deo = jumlah_garasi_jet_deo * jumlah_jet_per_garasi

print(total_jet_deo)
# Out:
# 21

# %%
#Pembagian

jet_pribadi_deo = 21
jumlah_anak_yatim = 6

jet_tiap_anak_yatim = jet_pribadi_deo / jumlah_anak_yatim

print(jet_tiap_anak_yatim)
# Out:
# 3.5

# %%
#Pembagian

jet_pribadi_deo = 21
jumlah_anak_yatim = 6

jet_tiap_anak_yatim = jet_pribadi_deo // jumlah_anak_yatim

print(jet_tiap_anak_yatim)
# Out:
# 3

# %%
#Sisa Bagi

total_jet_deo = 21
jumlah_anak_yatim = 6

sisa_jet_deo = total_jet_deo % jumlah_anak_yatim

print(sisa_jet_deo)
# Out:
# 3

# %%
sisi = 2

luas_persegi = sisi** 2

print(luas_persegi)
# Out:
# 4

# %%
sisi= 2

volume_kubus = sisi** 3

print(volume_kubus)
# Out:
# 8

# %%
luas_persegi = 4

sisi= luas_persegi ** (1/2)

print(sisi)
# Out:
# 2.0

# %%
volume_kubus = 8

sisi = volume_kubus ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# #jenis-jenis tipe variabel

# %%
#Float
a = 0.0
print (a)
type(a)
# Out:
# 0.0
# float

# %%
b = 10
print (b)
type (b)
# Out:
# 10
# int

# %%
c = '89342hk72!'
print(c)
type(c)
# Out:
# 89342hk72!
# str

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %%
f = -2.5
print(f)
type(f)
# Out:
# -2.5
# float

# %%
h = 0
print(h)
type(h)
# Out:
# 0
# int

# %%
h = True
print(h)
type(h)
# Out:
# True
# bool

# %%
i = int(h)
print(i)
type(i)
# Out:
# 1
# int

# %%
k = "shinta"
print(k)
type(k)
# Out:
# shinta
# str

# %%
g = bool(k)
print(g)
type(g)
# Out:
# True
# bool

# %% [markdown]
# #Mengubah Tipe Variabel

# %%
z = 5
print(z)
type(z)
# Out:
# 5
# int

# %%
y = float(z)
print(y)
type(y)
# Out:
# 5.0
# float

# %%
q = 10.0
print(q)
type (q)
# Out:
# 10.0
# float

# %%
p = int(q)
print(p)
type(p)
# Out:
# 10
# int

# %%
s = bool(q)
print(s)
type(s)
# Out:
# True
# bool

# %%
m = 0.0
print(m)
type(m)
# Out:
# 0.0
# float

# %%
n = bool(m)
print(n)
type(n)
# Out:
# False
# bool

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %%
print(2**3 == 8)
# Out:
# True

# %%
a = 8

b = 9

C = 10

print(a>b)
# Out:
# False

# %%
print(a>8)
# Out:
# False

# %%
print(a>=8)
# Out:
# True

# %%
nilai_kka = 76

kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>5 and 3<4)
# Out:
# True

# %%
print(9>7 and 5<1)
# Out:
# False

# %%
print(5<1 or 6>2)
# Out:
# True

# %%
print(not (5>1 or 6>2))
# Out:
# False

# %%
print(not (7<1 or 5>=4))
# Out:
# False

# %%
print(not 3<1)
# Out:
# True

# %%
iq_min = 125

usia_max = 25

iq_rizal = 130

usia_rizal = 26

print(iq_rizal >= iq_min and usia_rizal < usia_max)
# Out:
# False

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkan panjang persegi panjang (cm): "))

lebar = int(input("Masukkan lebar persegi panjang (cm): "))

luas = panjang * lebar

print (f"Luas persegi panjang yaitu {luas} cm^2.")
# Out:
# Masukkan panjang persegi panjang (cm): 7
# Masukkan lebar persegi panjang (cm): 3
# Luas persegi panjang yaitu 21 cm^2.

# %%
pi = (22/7)

volume_bola = (4/3) * pi * jari_jari * jari_jari * jari_jari
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2573409576.py in <cell line: 0>()
#       1 pi = (22/7)
#       2
# ----> 3 volume_bola = (4/3) * pi * jari_jari * jari_jari * jari_jari
#
# NameError: name 'jari_jari' is not defined
