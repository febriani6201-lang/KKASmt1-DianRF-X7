# %% [markdown]
# <a href="https://colab.research.google.com/github/febriani6201-lang/KKASmt1-DianRF-X7/blob/main/Aplikasi_sederhana_Febri_x_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nama :Dian Retno Febriani
# kelas :X.7
# Absen :10

# %%
pi = 22/7
jari_jari = float(input("Masukan jari jari bola"))


volume = 3/4 * pi * jari_jari**3

print (f"volume dengan jari jari {jari_jari} cm adalah {volume:.2f}")
# Out:
# Masukan jari jari bola14
# volume dengan jari jari 14.0 cm adalah 6468.00
