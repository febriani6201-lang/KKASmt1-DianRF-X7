# %% [markdown]
# <a href="https://colab.research.google.com/github/febriani6201-lang/KKASmt1-DianRF-X7/blob/main/Fungsi_print_Febri_X_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Dian Retno Febriani
#
# Kelas:X-7
#
# No. Absen:10

# %% [markdown]
# #Menampilkan teks bebas dengan tanda kutip

# %%
print("Hello World ")
# Out:
# Hello World

# %%
print ("Dian Retno Febriani ")
# Out:
# Dian Retno Febriani

# %% [markdown]
# #Menampilkan Variabel Integar

# %%
usia = 15
print (usia)
# Out:
# 15

# %%
beratbadan=50
print(beratbadan)
# Out:
# 50

# %%
tinggibadan=163
print(tinggibadan)
# Out:
# 163

# %% [markdown]
# #Menampilkan teks bebas dan nilai variabel

# %%
print("Tinggi badan:", tinggibadan)
# Out:
# Tinggi badan: 163

# %%
print("usia Anda:" + str (usia))
# Out:
# usia Anda:15

# %%
LuasMAN=1.1
print("LuasMAN adalah " + str (LuasMAN) + " kilometer persegi. ")
# Out:
# LuasMAN adalah 1.1 kilometer persegi.

# %%
print (f"LuasMAN adalah {LuasMAN} kilometer persegi. ")
# Out:
# LuasMAN adalah 1.1 kilometer persegi.

# %%
harga_telur=26000
nama_pembeli="Febri"

print("Harga telur adalah" , harga_telur, "per kilogram")
print("Nama pembeli telur adalah", nama_pembeli)
# Out:
# Harga telur adalah 26000 per kilogram
# Nama pembeli telur adalah Febri

# %%
print("Harga telur adalah" + str(harga_telur) + "per kilogram")
print("Nama pembeli telur adalah", nama_pembeli)
# Out:
# Harga telur adalah26000per kilogram
# Nama pembeli telur adalah Febri

# %%
print(f"Harga telur adalah {harga_telur} per kilogram")
print(f"Nama pembeli telur adalah {nama_pembeli}")
# Out:
# Harga telur adalah 26000 per kilogram
# Nama pembeli telur adalah Febri

# %% [markdown]
# #Escape character

# %%
print ("Nama: Dian Retno Febriani ")
print ("Kelas: X. 7")
print ("Nomor absen:10")
# Out:
# Nama: Dian Retno Febriani
# Kelas: X. 7
# Nomor absen:10

# %%
print ("Nama\t\t: Dian Retno Febriani\nKelas\t\t: X.7\nNomor absen\t:10")
# Out:
# Nama		: Dian Retno Febriani
# Kelas		: X.7
# Nomor absen	:10

# %%
print("""Nama:Dian Retno Febriani
kelas:X.7
Nomor absen:10""")
# Out:
# Nama:Dian Retno Febriani
# kelas:X.7
# Nomor absen:10

# %%
print ("Nama:Habib Jafar")
# Out:
# Nama:Habib Jafar

# %%
print ('Nama:Habib Jafar')
# Out:
# Nama:Habib Jafar

# %%
print('Nama:Habib Ja\'far')
# Out:
# Nama:Habib Ja'far

# %%
print("Nama:Habib Ja'far")
# Out:
# Nama:Habib Ja'far

# %%
print ("Bu Shinta berkata, \"Tentang fokus sejenak!\".")
# Out:
# Bu Shinta berkata, "Tentang fokus sejenak!".

# %%
print('Bu Shinta berkata, "Tenang fokus sejenak!".')
# Out:
# Bu Shinta berkata, "Tenang fokus sejenak!".

# %%
print("Lokasi penyimpanan tugas KKA ada di local disk D:\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA ada di local disk D:\KKA\Tugas

# %% [markdown]
# #Parameter Fungsi print

# %%
Tanggal=5
Bulan="Februari"
Tahun=2010

#05-Februari-2010
print(Tanggal)
print(Bulan)
print(Tahun)
# Out:
# 5
# Februari
# 2010

# %%
#05-Febuari-2010
print(Tanggal, Bulan, Tahun, sep="-")
# Out:
# 5-Februari-2010

# %%
#05-Febuari-2010
print (Tanggal, end="-")
print(Bulan, end="-")
print (Tahun)
# Out:
# 5-Februari-2010
